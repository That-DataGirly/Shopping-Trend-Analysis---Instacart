# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv ("dirty_instacart_sales.csv")

# %%
data = df.copy()

# %%
data
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
data.describe()
# Out:
#        Transaction ID   Item Quantity Price Per Unit Total Spent  \
# count           10000   9667     9862           9821        9827
# unique          10000     10        7              8          19
# top       TXN_1961373  Juice        5            3.0         6.0
# freq                1   1171     2013           2429         979
#
#         Payment Method  Location Transaction Date
# count             7421      6735             9841
# unique               5         4              367
# top     Digital Wallet  Takeaway          UNKNOWN
# freq              2291      3022              159

# %%
data.shape
# Out:
# (10000, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
data.isna().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# np.int64(6826)

# %%
(df.isna().sum() / len(df)) * 100
# Out:
# Transaction ID       0.00
# Item                 3.33
# Quantity             1.38
# Price Per Unit       1.79
# Total Spent          1.73
# Payment Method      25.79
# Location            32.65
# Transaction Date     1.59
# dtype: float64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Transaction ID, Item, Quantity, Price Per Unit, Total Spent, Payment Method, Location, Transaction Date]
# Index: []

# %%
columns=["Quantity", "Item", "Total Spent"]
data[columns]
# Out:
#      Quantity      Item Total Spent
# 0           2    Coffee         4.0
# 1           4      Cake        12.0
# 2           4    Cookie       ERROR
# 3           2     Salad        10.0
# 4           2    Coffee         4.0
# ...       ...       ...         ...
# 9995        2    Coffee         4.0
# 9996        3       NaN         3.0
# 9997        4    Coffee         8.0
# 9998        3    Cookie         3.0
# 9999        3  Sandwich        12.0
#
# [10000 rows x 3 columns]

# %%
data.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='object')

# %%
df["Quantity"]
# Out:
# 0       2
# 1       4
# 2       4
# 3       2
# 4       2
#        ..
# 9995    2
# 9996    3
# 9997    4
# 9998    3
# 9999    3
# Name: Quantity, Length: 10000, dtype: object

# %%
data = df.copy()

# %%
data["Item"].value_counts(dropna=False)
# Out:
# Item
# Juice       1171
# Coffee      1165
# Salad       1148
# Cake        1139
# Sandwich    1131
# Smoothie    1096
# Cookie      1092
# Tea         1089
# UNKNOWN      344
# NaN          333
# ERROR        292
# Name: count, dtype: int64

# %%
data["Item"].replace(["UNKNOWN", "ERROR"], np.nan)
# Out:
# 0         Coffee
# 1           Cake
# 2         Cookie
# 3          Salad
# 4         Coffee
#           ...
# 9995      Coffee
# 9996         NaN
# 9997      Coffee
# 9998      Cookie
# 9999    Sandwich
# Name: Item, Length: 10000, dtype: object

# %%
data["Item"]=data["Item"].replace(["UNKNOWN", "ERROR"], np.nan )

# %%
data["Item"].value_counts(dropna=False)
# Out:
# Item
# Juice       1171
# Coffee      1165
# Salad       1148
# Cake        1139
# Sandwich    1131
# Smoothie    1096
# Cookie      1092
# Tea         1089
# NaN          969
# Name: count, dtype: int64

# %%
data['Price Per Unit'].value_counts(dropna=False)
# Out:
# Price Per Unit
# 3.0        2429
# 4.0        2331
# 2.0        1227
# 5.0        1204
# 1.0        1143
# 1.5        1133
# ERROR       190
# NaN         179
# UNKNOWN     164
# Name: count, dtype: int64

# %%
data["Price Per Unit"]=data["Price Per Unit"].replace(["UNKNOWN", "ERROR"], np.nan)

# %%
data["Price Per Unit"].value_counts(dropna=False)
# Out:
# Price Per Unit
# 3.0    2429
# 4.0    2331
# 2.0    1227
# 5.0    1204
# 1.0    1143
# 1.5    1133
# NaN     533
# Name: count, dtype: int64

# %%
data['Total Spent'].value_counts(dropna=False)
# Out:
# Total Spent
# 6.0        979
# 12.0       939
# 3.0        930
# 4.0        923
# 20.0       746
# 15.0       734
# 8.0        677
# 10.0       524
# 2.0        497
# 9.0        479
# 5.0        468
# 16.0       444
# 25.0       259
# 7.5        237
# 1.0        232
# 4.5        225
# 1.5        205
# NaN        173
# UNKNOWN    165
# ERROR      164
# Name: count, dtype: int64

# %%
data["Total Spent"]=data['Total Spent'].replace(["UNKNOWN", "ERROR"], np.nan)

# %%
data["Total Spent"].value_counts(dropna=False)
# Out:
# Total Spent
# 6.0     979
# 12.0    939
# 3.0     930
# 4.0     923
# 20.0    746
# 15.0    734
# 8.0     677
# 10.0    524
# NaN     502
# 2.0     497
# 9.0     479
# 5.0     468
# 16.0    444
# 25.0    259
# 7.5     237
# 1.0     232
# 4.5     225
# 1.5     205
# Name: count, dtype: int64

# %%
data.isin(["ERROR", "UNKNOWN"]).sum()
# Out:
# Transaction ID        0
# Item                  0
# Quantity            341
# Price Per Unit        0
# Total Spent           0
# Payment Method      599
# Location            696
# Transaction Date    301
# dtype: int64

# %%
data.replace(["ERROR", "UNKNOWN"], np.nan, inplace=True)

# %%
data.isin(["ERROR", "UNKNOWN"]).sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
data["Quantity"] = pd.to_numeric(data["Quantity"])

# %%
data["Price Per Unit"] = pd.to_numeric(data["Price Per Unit"])

# %%
  
data["Total Spent"] = pd.to_numeric(data["Total Spent"])

# %%
data["Transaction Date"] = pd.to_datetime(data["Transaction Date"])

# %%
data
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    Coffee       2.0             2.0          4.0
# 1       TXN_4977031      Cake       4.0             3.0         12.0
# 2       TXN_4271903    Cookie       4.0             1.0          NaN
# 3       TXN_7034554     Salad       2.0             5.0         10.0
# 4       TXN_3160411    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    Coffee       2.0             2.0          4.0
# 9996    TXN_9659401       NaN       3.0             NaN          3.0
# 9997    TXN_5255387    Coffee       4.0             2.0          8.0
# 9998    TXN_7695629    Cookie       3.0             NaN          3.0
# 9999    TXN_6170729  Sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# ...

# %%
data.to_csv('cleaned_dirty_data.csv', index=False)
